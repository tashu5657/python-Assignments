# %%
units = int(input("Enter number of units consumed: "))
bill = 0

if units > 100:
    units = units - 100

    if units > 100:
        bill = bill + (100 * 5)
        units = units - 100

        if units > 0:
            bill = bill + (units * 10)
    else:
        bill = bill + (units * 5)

print("Total Electricity Bill Amount = Rs", bill)
# Out:
# Enter number of units consumed:  350
# Total Electricity Bill Amount = Rs 2000

# %%
percentage = float(input("Enter your percentage: "))

if percentage > 90:
    print("Grade: A")

elif percentage > 80 and percentage <= 90:
    print("Grade: B")

elif percentage >= 60 and percentage <= 80:
    print("Grade: C")

else:
    print("Grade: D")
# Out:
# Enter your percentage:  75
# Grade: C

# %%
age1 = int(input("Enter age of person 1: "))
age2 = int(input("Enter age of person 2: "))
age3 = int(input("Enter age of person 3: "))
age4 = int(input("Enter age of person 4: "))

youngest = age1

if age2 < youngest:
    youngest = age2

if age3 < youngest:
    youngest = age3

if age4 < youngest:
    youngest = age4

print("The youngest age is:", youngest)
# Out:
# Enter age of person 1:  19
# Enter age of person 2:  13
# Enter age of person 3:  14
# Enter age of person 4:  12
# The youngest age is: 12

# %%
salary = float(input("Enter your salary: "))
years = int(input("Enter your years of work: "))

bonus = 0

if years > 10:
    bonus = salary * 0.10

elif years >= 6 and years <= 10:
    bonus = salary * 0.08

else:
    bonus = salary * 0.05

print("Net Bonus Amount = Rs", bonus)
# Out:
# Enter your salary:  40000
# Enter your years of work:  4
# Net Bonus Amount = Rs 2000.0

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if (a > b and a < c) or (a < b and a > c):
    print("Second largest number is:", a)

elif (b > a and b < c) or (b < a and b > c):
    print("Second largest number is:", b)

else:
    print("Second largest number is:", c)
# Out:
# Enter first number:  34
# Enter second number:  23
# Enter third number:  43
# Second largest number is: 34

# %%
marked_price = float(input("Enter the marked price: "))

discount = 0

if marked_price > 10000:
    discount = marked_price * 0.20

elif marked_price > 7000 and marked_price <= 10000:
    discount = marked_price * 0.15

else:
    discount = marked_price * 0.10

net_amount = marked_price - discount

print("Discount Amount = Rs", discount)
print("Net Amount to Pay = Rs", net_amount)
# Out:
# Enter the marked price:  8000
# Discount Amount = Rs 1200.0
# Net Amount to Pay = Rs 6800.0

# %%
english = int(input("Enter marks of English: "))
math = int(input("Enter marks of Math: "))
science = int(input("Enter marks of Science: "))
social = int(input("Enter marks of Social Studies: "))

if english > 80 and math > 80 and science > 80 and social > 80:
    print("Stream Allotted: Science Stream")

elif english > 80 and math > 50 and science > 50:
    print("Stream Allotted: Commerce Stream")

elif english > 80 and social > 80:
    print("Stream Allotted: Humanities Stream")

else:
    print("No stream allotted as per criteria")
# Out:
# Enter marks of English:  85
# Enter marks of Math:  76
# Enter marks of Science:  82
# Enter marks of Social Studies:  69
# Stream Allotted: Commerce Stream

# %%
number = int(input("Enter a number: "))

if number % 5 == 0:
    print("Hello")
else:
    print("Bye")
# Out:
# Enter a number:  20
# Hello

# %%
number = int(input("Enter a number: "))

last_digit = number % 10

if last_digit % 3 == 0:
    print("The last digit is divisible by 3")
else:
    print("The last digit is not divisible by 3")
# Out:
# Enter a number:  69
# The last digit is divisible by 3

# %%
number = int(input("Enter a number: "))

last_digit = number % 10

if last_digit % 3 == 0:
    print("The last digit is divisible by 3")
else:
    print("The last digit is not divisible by 3")
# Out:
# Enter a number:  54
# The last digit is not divisible by 3

# %%
number = int(input("Enter a number: "))

if number >= 100 and number <= 999:
    print("The number is a three-digit number")
else:
    print("The number is not a three-digit number")
# Out:
# Enter a number:  567
# The number is a three-digit number

# %%
number = int(input("Enter a number: "))

if number >= 100 and number <= 999:
    print("The number is a three-digit number")
else:
    print("The number is not a three-digit number")
# Out:
# Enter a number:  67
# The number is not a three-digit number
